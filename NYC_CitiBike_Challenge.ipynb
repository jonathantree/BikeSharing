# %%
import pandas as pd
import os

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
ride_data_to_load = os.path.join("Data", "201908-citibike-tripdata.csv")
# Read the Ride Data and create dataframe
ride_data_df = pd.read_csv(ride_data_to_load)

# %%
#Check the first 20 records
ride_data_df.head(n=20)
# Out:
#     tripduration                 starttime                  stoptime  \
# 0            393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1            627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2           1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3           1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4           1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
# 5            632  2019-08-01 00:00:11.8060  2019-08-01 00:10:43.9590
# 6            117  2019-08-01 00:00:18.2010  2019-08-01 00:02:15.8600
# 7            378  2019-08-01 00:00:22.0840  2019-08-01 00:06:40.9350
# 8           1102  2019-08-01 00:00:22.0870  2019-08-01 00:18:44.3890
# 9           1733  2019-08-01 00:00:22.5580  2019-08-01 00:29:15.9080
# 10           885  2019-08-01 00:00:27.3260  2019-08-01 00:15:12.6400
# 11           505  2019-08-01 00:00:30.6680  2019-08-01 00:08:56.0820
# 12           620  2019-08-01 00:00:33.1190  2019-08-01 00:10:53.4140
# ...

# %%
#Check the last 20 records
ride_data_df.tail(n=20)
# Out:
#          tripduration                 starttime                  stoptime  \
# 2344204          1471  2019-08-31 23:59:07.7590  2019-09-01 00:23:38.9320
# 2344205           295  2019-08-31 23:59:19.3260  2019-09-01 00:04:15.2720
# 2344206          1370  2019-08-31 23:59:21.2130  2019-09-01 00:22:11.2350
# 2344207           452  2019-08-31 23:59:23.8080  2019-09-01 00:06:56.2010
# 2344208           768  2019-08-31 23:59:23.9280  2019-09-01 00:12:12.5110
# 2344209          1591  2019-08-31 23:59:26.5030  2019-09-01 00:25:58.2750
# 2344210          1648  2019-08-31 23:59:34.2430  2019-09-01 00:27:03.0340
# 2344211          1167  2019-08-31 23:59:34.4130  2019-09-01 00:19:01.8530
# 2344212           921  2019-08-31 23:59:34.5920  2019-09-01 00:14:56.1080
# 2344213           683  2019-08-31 23:59:34.8270  2019-09-01 00:10:58.3350
# 2344214           532  2019-08-31 23:59:36.1200  2019-09-01 00:08:28.7850
# 2344215           838  2019-08-31 23:59:38.0510  2019-09-01 00:13:36.8530
# ...

# %%
# 2. Check the datatypes of your columns. 
ride_data_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# 3. Convert the 'tripduration' column to datetime datatype
ride_data_df.tripduration = pd.to_datetime(ride_data_df.tripduration, unit='s')
ride_data_df.tripduration
# Out:
# 0         1970-01-01 00:06:33
# 1         1970-01-01 00:10:27
# 2         1970-01-01 00:18:52
# 3         1970-01-01 00:29:40
# 4         1970-01-01 00:25:17
#                   ...
# 2344219   1970-01-01 00:03:36
# 2344220   1970-01-01 00:01:57
# 2344221   1970-01-01 00:26:54
# 2344222   1970-01-01 00:21:41
# 2344223   1970-01-01 00:06:59
# Name: tripduration, Length: 2344224, dtype: datetime64[ns]

# %%
# 4. Check the datatypes of your columns. 
ride_data_df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
# 5. Export the Dataframe as a new CSV file without the index.
ride_data_df.to_csv("201908-citibike-tripdata_converted.csv", index=False)
